# %%
import numpy as np
import matplotlib.pyplot as plt
import math

# %%
m = 1 # kg
c = 2.5 # N-s/m
k = 60 # N/m
F = 25 # N
ω = 15**0.5

# %%
wn = np.sqrt(k/m)
z = c / (2 * np.sqrt(m * k))
wd = np.sqrt(1 - z**2) * wn

# %%
t = np.linspace(0, 20*2*np.pi/wn, 100)
C1 = x0
C2 = (v0 + z * wn * x0) / wd
x = C1 * np.exp(-z * wn * t) * np.cos(wd * t) + C2 * np.exp(-z * wn * t) * np.sin(wd * t)

# %%
plt.plot(t, x)
plt.xlabel('Time (s)')
plt.ylabel('Displacement (m)')
plt.title('Displacement Response of Spring-Mass-Dashpot System')
plt.grid()
plt.show()

# %%
import numpy as np
from scipy.integrate import solve_ivp
import matplotlib.pyplot as plt

def spring_mass_dashpot(t, y, m, c, k):
    x, v = y
    dxdt = v
    dvdt = -(c/m)*v - (k/m)*x + np.sin(2*np.pi*t)
    return dxdt, dvdt

t_eval = np.linspace(0, 20/2/np.pi, 1000)
sol = solve_ivp(lambda t, y: spring_mass_dashpot(t, y, 1, 2.5, 60), [0, 20/2/np.pi], [1.0, 5.0], t_eval=t_eval)

plt.plot(sol.t, sol.y[0])
plt.xlabel('Time (s)')
plt.ylabel('Displacement (cm)')
plt.grid()
plt.show()


peak = max(sol.y[0]) - min(sol.y[0])
peak_positive = peak / 2
print("Peak positive amplitude: ", peak_positive, " cm")
# Out:
# Peak positive amplitude:  0.924117052463229  cm

# %%
import numpy as np
import matplotlib.pyplot as plt

m = 1 # kg
c = 2.5 # N-s/m
k = 60 # N/m
x0 = 0.01 # m
v0 = 0.05 # m/s
wn = np.sqrt(k/m)
T = 2*30*pi/wn
t = np.linspace(0, T, 1000)

z = .44 * np.sin(np.sqrt(15)*t - 3 * np.pi * (1/50))

plt.plot(t, z)
plt.xlabel('t')
plt.ylabel('z')
plt.title('vibration response for 30 cycles')
plt.grid()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

m = 1 # kg
c = 2.5 # N-s/m
k = 60 # N/m
x0 = 0.01 # m
v0 = 0.05 # m/s
wn = np.sqrt(k/m)
T = 2*wn
t = np.linspace(0, T, 1000)
m = 1/np.sqrt((1 - t**2)**2 + 0.32*t**2)

plt.plot(t, m)
plt.xlabel('t')
plt.ylabel('m')

plt.title('Magnification factor for a range of frequencies')
plt.show()
